# %% [markdown]
# # Proyecto Clase - Análisis de homogeneidad covariables formadoras de suelo
# ## Visualización de los procesos en Data_peparation
# 1. Visualización del DEM cortado y reproyectado
# 2. Visualización de imagen sentinel reproyectada

# %%
import sys
sys.path.append("/notebooks/Proyecto_Clase/src")
import visualization_tools
import importlib
importlib.reload(visualization_tools)

# Visualizar el DEM
visualization_tools.visualizar_dem('/notebooks/Insumos_Proyecto_Clase/Raster_Cortados/DEM_MVV.tif')

# Visualizar las bandas de Sentinel-2
visualization_tools.visualizar_multibanda('/notebooks/Insumos_Proyecto_Clase/Raster_Cortados/Ind_MVV.tif')
# Out:
# Imagen Multibanda graficando ... Cantidad de bandas: 8
